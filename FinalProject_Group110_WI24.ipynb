# %% [markdown]
# # Mental Health of Pregnant Women during the COVID-19 Pandemic
# ![Screen_Shot_2024-03-20_at_8.56.13_PM.png](attachment:Screen_Shot_2024-03-20_at_8.56.13_PM.png)
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# # Names
#
# * Sophia Ashraf
# * Dylan Oquendo
# * Karun Mokha
# * Jake Kondo
# * Ekrem Ersoz
#
# # Abstract
#
# **Introduction:**
#
# The COVID-19 pandemic has brought forth unprecedented challenges, affecting target and at risk populations across the globe. It is already well known that pregnant women are significantly susceptible to increased mortality and morbidity due to infectious diseases (C. M Lam et al., 2004). Recent research has shown that this vulnerability is heightened by significant physiological changes during pregnancy throughout their immune system, thus increasing their risk of infection of diseases, including COVID-19 (Wastnedge et al., 2021). In addition, birth related fears have been connected to increased psychological distress with negative outcomes for both birth and infant development, with birth related fears being present amongst ~25% of a pregnant population that ~10% of also reported that the fear impaired daily activities and the ability to the cope with labor (Molgora et al., 2018; Ding et al., 2014; Vismara et al., 2020). Despite this research on fear and pregnancy, very little is known about how health-related fears, such as fear of COVID-19, affect a pregnant woman’s maternal mental health and childbirth outcomes. This lack of research is incredibly important because it limits a health system’s ability to combat the challenges faced by pregnant individuals, who are at risk when pandemics arise in the future.
#
# This study, which leverages data from the Pregnancy during the COVID-19 Pandemic project, (PdP), had the goal of further dissecting the interplay between mental health disturbances and specific pandemic-related events and their subsequent effect if any on pregnancy outcomes. Using a variety of statistical tools, including pairplot visualizations, correction analyses, and logistic regression, our research hopes to shine light onto the relationships between perceived threat levels of COVID-19, anxiety, depression, and the likelihood of NICU admission. This study is focused on highlighting the significant, long lasting impacts of COVID-19, including investigating critical milestones such as the first national COVID-19 vaccine rollout, and the mental health of COVID-19 era pregnancies. Our exploratory data analysis spins over the pre and post-vaccine time periods, offering an in depth look at the shifting landscape of pregnant women’s mental health following the first vaccine rollout.
#
# Our findings showcased consistent associations between perceived pandemic threat levels and markers of mental health distress across both of our observed periods. We found a significant positive correlation between perceived threat level and negative mental health indicators, highlighting the effectiveness of pandemic-related stressors on maternal mental well being. Despite this, our logistic regression found that perceived threats of COVID-19  are not significant predictors of NICU admissions.
#
# Though our overall goal of the study was to highlight the importance of mental health care for pregnant women during high stress inducing events such as COVID-19, our findings reinforces the need for more holistic health care strategies that include support for pregnant woman, and specifically address the risk of physiological changes and diseases during pregnancy and alleviate the perceived fears related to their pregnancy and birth. In conclusion, our findings show the importance of addressing mental health concerns among pregnant individuals, particularly during times of stress such as the COVID-19 pandemic. While the introduction of vaccines may have lessened some psychological distress, perceived threat levels and mental health indicators exhibited that there was still a need for maternal well-being.
#
# **Methods:**
#
# The data used in our study we found on kaggle, and it comes from the Pregnancy During the COVID-19 Pandemic study (PdP) (Geisbrechtet al., 2021), which conducted analysis from April to December of 2020. The data comes under the ethics approval of the University of Calgary Conjoint Health Research Ethics Board of Canada. The participants gave consent of data and  took a survey reporting their demographic, background, and health history, as well as other variables which will shortly be described. The data was collected using Research Electronic Data Capture REDCap, a trusted methodology and workflow process for translational research informatics (Harris et al., 2009). We divided the data into two time periods, pre vaccine and post vaccine, post vaccine being when Canada released the COVID-19 vaccines for the public so we can further analyze the topic beyond what the original research was on. Knowing how much mental health can be affected by events such as the release of the vaccine, we created models and compared the two time periods along with the other variables to see if these events had any impact on the mental health of pregnant women.
#
# **Participants:**
#
# The participant requirements to enroll in this study was a minimum age of 17 years and a maximum gestation age of 35, a Canadian citizen, and English or French speaking. That was the only exclusion criteria for this study. The participants were then recruited via social media ads in both French and English.
#
#
#
# **Citations:**
#
# Ahmad, Monica, and Laura Vismara. "The psychological impact of COVID-19 pandemic on women’s mental health during pregnancy: A rapid evidence review." International Journal of Environmental Research and Public Health 18.13 (2021): 7112.
#
# Ding, Xiu-Xiu, et al. "Maternal anxiety during pregnancy and adverse birth outcomes: a systematic review and
# meta-analysis of prospective cohort studies." Journal of affective disorders 159 (2014): 103-110.
#
# Giesbrecht, Gerald F., et al. "Protocol for the pregnancy during the COVID-19 pandemic (PdP) study: a longitudinal
# cohort study of mental health among pregnant Canadians during the COVID-19 pandemic and developmental outcomes in their children." JMIR research protocols 10.4 (2021): e25407.
#
# Harris, Paul A., et al. "Research electronic data capture (REDCap)—a metadata-driven methodology and workflow
# process for providing translational research informatics support." Journal of biomedical informatics 42.2 (2009): 377-381.
#
#
# Lam, Chui Miu, et al. "A case‐controlled study comparing clinical course and outcomes of pregnant and
# non‐pregnant women with severe acute respiratory syndrome." BJOG: An International Journal of Obstetrics & Gynaecology 111.8 (2004): 771-774.
#
# Molgora, Sara, et al. "Fear of childbirth in primiparous Italian pregnant women: The role of anxiety, depression, and couple adjustment." Women and Birth 31.2 (2018): 117-123.

# %% [markdown]
# # Research Question

# %% [markdown]
# **How did the interplay between mental health and specific Covid-19-related events influence pregnancy outcomes, and what novel patterns emerge when comparing pre-vaccine and post-vaccine introduction phases?**
#
# **Sub Questions:**
#
# **Normal time data (overall population):**<br>
# Analyze pregnancy outcomes data from periods before the COVID-19 pandemic as a baseline. This will help establish what "normal" outcomes look like, against which pandemic-era outcomes can be compared.<br>
#
# **Was it related to mental health:**<br>
# Investigate whether changes in pregnancy outcomes during the COVID-19 pandemic correlate with reported changes in mental health statistics. This involves collecting data on mental health issues among pregnant individuals during the pandemic and comparing these with pregnancy outcomes.<br>
#
# **How did these relate to large events (e.g., vaccines)?**<br>
# Examine the timeline of major Covid-19-related events, such as lockdowns, infection waves, and the introduction of vaccines, and analyze their impact on mental health and pregnancy outcomes. This could involve comparing pregnancy outcomes and mental health data before and after such events to identify any significant changes or trends.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The impact that COVID-19 has had on mental health around the globe has been acknowledged and studied by scientific researchers to examine its effects, particularly on specific “at risk” populations such as pregnant and postpartum women. The World Health Organization (WHO) estimates anxiety and depression prevalence increased 25% globally during the height of the pandemic. A systematic review and meta-analysis conducted by Gayathri Delanerolle, Department of Health Care Science at Oxford, titled “The prevalence of mental ill-health in women during pregnancy and after childbirth during the COVID-19 pandemic” found a significant increase in negative mental health outcomes specifically in women who were pregnant and postpartum. They quantified depression, anxiety, and stress. They suggested that the increase in these conditions highlights a need for mental health resources amongst maternal healthcare services, especially during a pandemic as impactful as COVID-19. This research provides a strong empirical context for our group illustrating the vulnerability of pregnant women to negative mental health outcomes during the pandemic.
#
# For our project, we also wanted to contextualize maternal stress during pregnancy at times not during a pandemic so we have a measure to compare. In an article titled, “Prenatal developmental origins of behavior and mental health: The influence of maternal stress in pregnancy” Van den Bergh et al’s did a review on current research to find that stress during pregnancy can have long-lasting behavioral and mental health effects later in life. This includes affecting fetal development in a variety of ways including hormonal changes and affecting brain development. Overall the article highlights how critical the pregnancy period is for mothers, and how during extra stressful times there could be profound long-lasting effects on child development.
#
# These two studies serve as a foundation for our project as context for stress, and mental health in pregnant and postpartum women with a meta-analysis on mental health during the pandemic, and a systematic review of all current research on maternal stress and child development. Delanerolle et al. 's article found an increase in mental health issues amongst pregnant and postpartum women during the pandemic, while Van den Bergh et al’s comprehensive review gave us insight into the origins of prenatal mental health by highlighting cognitive and neurodevelopment dysfunction. These findings highlight the importance of our research question. Our goal is to examine the relationship between mental health during COVID-19 and pregnancy outcomes, our project aims to contribute to the prior research and understanding of these interactions and serve to assess maternal well-being during pandemic eras currently and in the future.
#
# In “Fear of COVID-19, mental health, and pregnancy outcomes in the pregnancy during the COVID-19 pandemic study”, the source of our data, they found that sociodemographic, health, and obstetric factors contributed to the increase in the fear of COVID-19 and associated adverse outcomes. The fear of COVID-19 is significantly linked to mental health issues and adverse pregnancy outcomes, even when controlling for other factors with the study suggesting that public health information and the evolving nature of the pandemic might inadvertently heighten fear. Using this knowledge, we will try to replicate and put our own twist by cleaning the data differently, splitting it into two groups: prevaccine and postvaccine, and running different models, with the goal of solidifying our hypothesis. We would like to see if outside factors not contributing to the original study made a definitive impact, as these events certainly have the potential to make changes regarding mental health, especially for those who fear COVID-19.
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8690287/<br>
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9883834/<br>
# https://pubmed.ncbi.nlm.nih.gov/28757456/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Increased stress and mental health challenges faced by pregnant individuals during the Covid-19 pandemic negatively impacted pregnancy outcomes. We arrived at our prediction by considering the radical effect of the Covid-19 pandemic on an individual’s emotional and mental well being. We also paired this with the already existing stress that a woman faces throughout her pregnancy, and came up with our hypothesis.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - **Dataset #1**
#   - Mental health in the pregnancy during the COVID-19
#   - https://www.kaggle.com/datasets/yeganehbavafa/mental-health-in-the-pregnancy-during-the-covid-19/data
#   - 5176 observations
#   - 15 variables
#
#
#
# **Variables:** Mental health indicators (e.g., levels of stress, anxiety, depression), pregnancy outcomes (e.g., gestational age at birth, birth weight, any complications), Covid-19 impact metrics (e.g., infection status, lockdown impact), major pandemic events timelines (e.g., start of lockdowns, vaccine rollouts).
#
# **Population:** Pregnant individuals during the COVID-19 pandemic, with a comparison group from before the pandemic as a baseline.
#
# **Time Period:** Data should span from before the COVID-19 pandemic (as a baseline) and continue through the pandemic, ideally with timestamps to align with major pandemic events for dynamic analysis.
#
# This dataset from the Pregnancy during the COVID-19 Pandemic (PdP) project includes variables such as maternal age, household income, maternal education levels, Edinburgh Postnatal Depression Scale (EPDS) scores, PROMIS Anxiety scores, gestational age at birth, delivery date, birth length and weight, delivery mode, NICU stay, survey language, and perceived threat levels to life and unborn baby due to COVID-19. These variables offer comprehensive insights into the socio-economic, psychological, and health-related aspects of pregnant individuals' experiences during the pandemic, allowing for a multifaceted analysis of the impact of COVID-19 on pregnancy outcomes.

# %% [markdown]
# ## Mental Health among pregnant women during the COVID-19

# %% [markdown]
# We want to import packages and libraries for our cleaning and analysis such as pandas, seaborn, matplotlib, numpy, sklearn, and scipy to optimize our process and have these libraries readily available.

# %%
import pandas as pd
import seaborn as sns
import copy
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from scipy.stats import pearsonr
from io import StringIO

import warnings
warnings.filterwarnings("ignore")
# Out:
# /var/folders/px/_70k765d22d1hlv8t1lktgw40000gn/T/ipykernel_28859/770778644.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Import the data file as **file_path** and read the file to start our cleaning process.

# %%
# Import the dataframe
file_path = 'Pregnancy During the COVID-19 Pandemic.csv'
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure of the dataset
df.head()
# Out:
#    OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0       1          38.3           $200,000+        Masters degree
# 1       2          34.6           $200,000+  Undergraduate degree
# 2       3          34.3  $100,000 -$124,999  Undergraduate degree
# 3       4          28.8  $100,000 -$124,999        Masters degree
# 4       5          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# ...

# %% [markdown]
# Drop rows with null values in **PROMIS_Anxiety, Birth_Length, Birth_Weight, NICU_Stay,** and **Edinburgh_Postnatal_Depression_Scale** as they have the potential to disrupt our analysis and we have sufficent enough data to go without the null data.

# %%
#Drop any row with null value for the values we are most interested in
df = df.dropna(subset=['PROMIS_Anxiety', 'Birth_Length', 'Birth_Weight', 'NICU_Stay', 'Edinburgh_Postnatal_Depression_Scale'])

# %% [markdown]
# Drop the **language** column as we do not need the langauage the patient speaks for our analysis.

# %%
#drop language column
df = df.drop('Language', axis=1)
df.drop(columns=['OSF_ID'], inplace=True)

# %% [markdown]
# Checking for **missing values** so we can identify which columns have missing values.

# %%
# Checking for missing values
missing_values = df.isnull().sum()

missing_values
# Out:
# Maternal_Age                                   3
# Household_Income                              20
# Maternal_Education                            14
# Edinburgh_Postnatal_Depression_Scale           0
# PROMIS_Anxiety                                 0
# Gestational_Age_At_Birth                       0
# Delivery_Date(converted to month and year)     0
# Birth_Length                                   0
# Birth_Weight                                   0
# Delivery_Mode                                  0
# NICU_Stay                                      0
# Threaten_Life                                  0
# Threaten_Baby_Danger                           0
# Threaten_Baby_Harm                             0
# dtype: int64

# %% [markdown]
# **Renaming** the columns to simpler names to make it easier to read when reading the table and data, while also allowing the data to fit as some of the columns name were quite long.

# %%
df.rename(columns={'Maternal_Age': 'mat_age',
                   'Household_Income': 'income',
                   'Maternal_Education': 'mat_edu',
                  'Edinburgh_Postnatal_Depression_Scale': 'depression',
                  'PROMIS_Anxiety': 'anxiety',
                  'Gestational_Age_At_Birth': 'birth_age_wk',
                  'Delivery_Date(converted to month and year)': 'birth_date',
                  'Birth_Length': 'birth_length_cm',
                  'Birth_Weight': 'birth_weight_g',
                  'Delivery_Mode': 'delivery',
                  'NICU_Stay': 'NICU',
                  'Threaten_Life': 'life_danger',
                  'Threaten_Baby_Danger': 'baby_danger',
                  'Threaten_Baby_Harm': 'virus_baby_harm'}, inplace=True)
df.head()
# Out:
#     mat_age              income               mat_edu  depression  anxiety  \
# 0      38.3           $200,000+        Masters degree         9.0     13.0
# 3      28.8  $100,000 -$124,999        Masters degree         9.0     20.0
# 4      36.5     $40,000-$69,999  Undergraduate degree        14.0     20.0
# 8      33.1  $100,000 -$124,999  College/trade school         1.0      7.0
# 13     29.2     $70,000-$99,999        Masters degree        14.0     17.0
#
#     birth_age_wk birth_date  birth_length_cm  birth_weight_g  \
# 0          39.71    Dec2020            49.20          3431.0
# 3          38.57    Dec2020            41.00          2534.0
# 4          39.86    Oct2020            53.34          3714.0
# 8          40.86    Nov2020            55.88          4480.0
# 13         41.00    Oct2020            47.00          3084.0
#
#                          delivery NICU life_danger baby_danger virus_baby_harm
# ...

# %% [markdown]
# Utilizing the **describe** function to see the statistics of the current data frame state as we want to get a better understanding of the data we are looking with.

# %%
# Summary statistics for numerical columns
summary_statistics = df.describe()


summary_statistics, missing_values
# Out:
# (           mat_age   depression      anxiety  birth_age_wk  birth_length_cm  \
#  count  5173.000000  5176.000000  5176.000000    5176.00000      5176.000000
#  mean     32.521322     9.738022    18.389104      39.33868        50.499834
#  std       4.140823     5.307232     5.950169       1.62486         4.433899
#  min      18.500000     0.000000     7.000000      24.86000        20.000000
#  25%      29.700000     6.000000    14.000000      38.57000        49.000000
#  50%      32.400000    10.000000    19.000000      39.57000        50.800000
#  75%      35.300000    13.000000    23.000000      40.43000        53.310000
#  max      49.000000    28.000000    35.000000      42.86000        70.000000
#
#         birth_weight_g
#  count     5176.000000
#  mean      3412.676005
#  std        534.564742
#  min        314.000000
#  25%       3119.000000
#  50%       3431.000000
#  75%       3742.000000
#  max       5968.000000  ,
#  Maternal_Age                                   3
# ...

# %% [markdown]
# We created a function named **standardize_income**, which takes in an input named income and standaredizes the income into numbers and removes symbols like "+". It then converts the income from a string to an integer so we can analyze it later on.

# %%
#this function converts the income into integer values, taking the maximum of those values with ranges
def standardize_income(income):
    if pd.isna(income):
        return np.nan

    if 'Less than' in income:
        return 20000

    # Handle open-ended values like '$200,000+'
    elif '+' in income:
        return 200000

    # Check if income is a range
    else:
        parts = income.replace('$', '').replace(',', '').replace(' ', '').split('-')
        #convert to int
        int_parts = [int(x) for x in parts]
        # Calculate maximum for ranges
        return int_parts[1]

# Assuming 'df' is your dataframe
df['income'] = df['income'].apply(standardize_income)

df.income.value_counts()
# Out:
# income
# 124999.0    1031
# 99999.0      922
# 149999.0     764
# 174999.0     667
# 200000.0     600
# 69999.0      555
# 199999.0     385
# 39999.0      178
# 20000.0       54
# Name: count, dtype: int64

# %% [markdown]
# We convert the **NICU** column from a string to 1's and 0's as these boolean values allow us to use different functions such as **.sum()** to see how many patients had NICU stays.

# %%
# Convert 'Yes'/'No' to 1/0 in NICU_Stay
df['NICU'] = df['NICU'].map({'Yes': 1, 'No': 0})
nicu_stay_yes_count = df['NICU'].sum()
nicu_stay_yes_count
# Out:
# 503

# %% [markdown]
# We convert the **birth_date** column to datetime as this will clean up our data along with giving us the ability to analyze it smoother for future uses.

# %%
# Let's check the data types of the 'birth_date' column in the DataFrame.
df.dtypes
#sort the data frame chronological dates
df = df.sort_values(by='birth_date')
#convert date format
df['birth_date'] = pd.to_datetime(df['birth_date'], errors='coerce')

# Display the sorted DataFrame
df
# Out:
#       mat_age    income               mat_edu  depression  anxiety  \
# 8818     30.8  149999.0  College/trade school        16.0     25.0
# 1070     36.7  149999.0  Undergraduate degree         8.0     14.0
# 4968     30.9  174999.0  Undergraduate degree         7.0     15.0
# 9832     38.6  200000.0  Undergraduate degree        11.0     28.0
# 3273     30.7  124999.0        Masters degree        16.0     27.0
# ...       ...       ...                   ...         ...      ...
# 9182     27.8   69999.0  College/trade school         9.0     20.0
# 160      38.6  200000.0        Masters degree         1.0     11.0
# 9272     33.1  174999.0  Undergraduate degree         7.0     18.0
# 5715     29.9  200000.0       Doctoral Degree        11.0      9.0
# 5523     35.7  149999.0        Masters degree         4.0     10.0
#
#       birth_age_wk birth_date  birth_length_cm  birth_weight_g  \
# 8818         37.14 2020-04-01            50.00          2722.0
# ...

# %% [markdown]
# We create a dictionary on the categorization of the **mat_edu** column as we want to shorten values such as **'Undergradute degree'** to **'UG'** for simplicity and better readibility. We then replaced the current values of **mat_edu** with the dictionary called **mapping** for the change to take effect on the column and used the **value_counts()** function to see how many patients were in each category.

# %%
# Clean the mother education column's values
mapping = {
    'Undergraduate degree': 'UG',
    'Masters degree': 'M',
    'College/trade school': 'C/T',
    'Doctoral Degree': 'PhD',
    'High school diploma': 'HS',
    'Less than high school diploma': '<HS'
}

# Replace values in the 'mat_edu' column using the mapping
df['mat_edu'] = df['mat_edu'].replace(mapping)

df.mat_edu.value_counts()
# Out:
# mat_edu
# UG     2137
# M      1162
# C/T    1048
# PhD     517
# HS      275
# <HS      23
# Name: count, dtype: int64

# %% [markdown]
# Using a similar process to **mat_edu**, we did the same for the **delivery** column as shorttening the values to one letter(**V & C**), which are super recognizable and better readibility.

# %%
# Similar cleaning for the delivery mode
mapping = {'Vaginally': 'V', 'Caesarean-section (c-section)': 'C'}
df['delivery'] = df['delivery'].replace(mapping)
df.delivery.value_counts()
# Out:
# delivery
# V    3665
# C    1511
# Name: count, dtype: int64

# %% [markdown]
# To finish off on our cleaning before moving to our analytical steps, we converted the columns **life_danger**, **baby_danger**, and **virus_baby_harm** to integers, as these columns alaready contained numbers and were used on a number scale, so converting to integers will allow us to analyze the column in a more efficent manner.

# %%
# Convert all the survey number responses to actual integers
df['life_danger'] = df['life_danger'].astype(int)
df['baby_danger'] = df['baby_danger'].astype(int)
df['virus_baby_harm'] = df['virus_baby_harm'].astype(int)
df.dtypes
# Out:
# mat_age                   float64
# income                    float64
# mat_edu                    object
# depression                float64
# anxiety                   float64
# birth_age_wk              float64
# birth_date         datetime64[ns]
# birth_length_cm           float64
# birth_weight_g            float64
# delivery                   object
# NICU                        int64
# life_danger                 int64
# baby_danger                 int64
# virus_baby_harm             int64
# dtype: object

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# ### Initial Analysis of mental health of preganant women
#
# ![Screenshot%202024-03-11%20at%202.19.58%20AM.png](attachment:Screenshot%202024-03-11%20at%202.19.58%20AM.png)

# %% [markdown]
# Given the multitude of variables in our dataset related to each mothers background, mental health status, and births, we have explored our dataset for possible outliers, skews, and trends that should align with common birth knowledge. For maternal age, we have a normal distribution centered around are thirty, suggesting the women of this dataset are mostly in their 30’s. Interestingly enough, the Edinburgh Postnatal Depression Scale Score is actually slightly right-skewed, meaning more respondents had lower depression scores, with fewer individuals reporting high levels of depression in their model’s assessment. We saw a similar trend in the PROMIS Anxiety Score as well. The Gestational Age at Birth distribution also had peaks at 38-40 weeks, indicating that the majority of our births in the dataset occurred on term, according to the WHO, who we compared our birth related values to. The majority of babies had a weight of 2500 to 4000 grams, which is within the normal range also according to the WHO.
#
# Furthermore, some other trends in our dataset amongst our variables were majority of our mothers were high or middle class, and majority spoke english with some french speakers (as our dataset comes from canadian population), and the absolute majority of our mothers received a college degree. The histograms for depression and anxiety scores hint at potential outliers in the higher score ranges, but these could just be cases of severe anxiety or depression, potentially people with overlapping conditions. In terms of our birth data weight and gestational age distributions seemed relatively clean, with no extreme outliers present. It will be important to keep in mind when we start running our models how we clean our data if we choose to reevaluate how we choose our null values or distributions, as we have some ranges to define relative to publicly known depression and birth knowledge (i.e how we compared values to the WHO).

# %% [markdown]
# ## First Analysis You Did - Give it a better title

# %%
# Classify births as either problematic or not depending on the birth outcomes
df['prob_preg'] = ((df['birth_weight_g'] < 2500) | (df['delivery'] == 'C') | (df['NICU'] == 1) | (df['birth_age_wk'] < 37)).astype(int)

# %%
# Now, define your date ranges for the prevaccine and postvaccine periods
# Vaccine started 2020-12-14, so 40 weeks past this date puts us at 2021-9-20
# But also, to keep it relatively equal, we will only look at the 12 months leading up to the vaccine start
# As our post dataframe only ranges 12 months
prevaccine_start = pd.to_datetime('2020-10-1')
prevaccine_end = pd.to_datetime('2021-9-19')
postvaccine_start = pd.to_datetime('2021-9-20')


# Filter the DataFrame for prevaccine and postvaccine periods
prevaccine_df = df[(df['birth_date'] <= prevaccine_end) & (df['birth_date'] >= prevaccine_start)]
postvaccine_df = df[(df['birth_date'] >= postvaccine_start)]

# Number of rows in the prevaccine subset
num_rows_prevaccine = prevaccine_df.shape[0]

# Number of rows in the postvaccine subset
num_rows_postvaccine = postvaccine_df.shape[0]

# Print the results
print(f"Number of rows in the prevaccine subset: {num_rows_prevaccine}")
print(f"Number of riws in the postvaccine subset: {num_rows_postvaccine}")
prevaccine_df.birth_date.value_counts().sort_index()
postvaccine_df
# Out:
# Number of rows in the prevaccine subset: 2923
# Number of riws in the postvaccine subset: 65
#        mat_age    income mat_edu  depression  anxiety  birth_age_wk  \
# 7014      30.2   69999.0      HS        19.0     22.0         37.29
# 10105     35.9  124999.0     C/T        10.0     19.0         37.71
# 5770      37.5   39999.0     PhD         7.0     22.0         41.57
# 9176      35.7  199999.0     C/T        12.0     18.0         38.86
# 3807      38.3  200000.0     PhD         0.0      9.0         39.71
# ...        ...       ...     ...         ...      ...           ...
# 3886      31.9   69999.0       M         5.0     11.0         41.43
# 160       38.6  200000.0       M         1.0     11.0         38.86
# 9272      33.1  174999.0      UG         7.0     18.0         38.14
# 5715      29.9  200000.0     PhD        11.0      9.0         41.00
# 5523      35.7  149999.0       M         4.0     10.0         40.86
#
# ...

# %%
problematic_pregnancies_by_date = df.groupby('birth_date')['prob_preg'].sum()

# Plot the number of problematic pregnancies over time
problematic_pregnancies_by_date.plot(marker='o', linestyle='-')

# Add a red line at the specific date
plt.axvline(x=pd.to_datetime('2020-12-14'), color='red', linestyle='--', label='Vaccination Start')
plt.axvline(x=pd.to_datetime('2021-9-20'), color='orange', linestyle='--', label='Pregnancy Out of Covid')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Number of Problematic Pregnancies')
plt.title('Number of Problematic Pregnancies Over Time')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Get the number of problematic pregnancies in the pre and post-covid dataframes

num_prob_preg_pre = prevaccine_df['prob_preg'].sum()
num_prob_preg_post = postvaccine_df['prob_preg'].sum()
print(num_prob_preg_pre)
num_prob_preg_post
# Out:
# 1056
# 21

# %%
prop_prob_preg_pre_covid = num_prob_preg_pre / len(prevaccine_df)
prop_prob_preg_post_covid = num_prob_preg_post / len(postvaccine_df)

plt.bar(['Pre-COVID', 'Post-COVID'], [prop_prob_preg_pre_covid, prop_prob_preg_post_covid])
plt.title('Proportion of Problematic Pregnancies')
plt.xlabel('Time Period')
plt.ylabel('Proportion')
plt.show()

# %%
# Since there is such a large difference in observations for the months post covid, we will plot ratios of each month as opposed to purely count
monthly_ratio = df.groupby('birth_date')['prob_preg'].mean()

# Plot the monthly ratio of problematic pregnancies over time
plt.plot(monthly_ratio.index, monthly_ratio, marker='o', linestyle='-')

# Add a red line at the specific date
plt.axvline(x=pd.to_datetime('2020-12-14'), color='red', linestyle='--', label='Vaccination Start')
plt.axvline(x=pd.to_datetime('2021-9-20'), color='orange', linestyle='--', label='Pregnancy Out of Covid')
# Add labels and title
plt.xlabel('Date')
plt.ylabel('Ratio of Problematic Pregnancies')
plt.title('Ratio of Problematic Pregnancies Over Time')

# Add legend
plt.legend()
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
postvaccine_df = postvaccine_df.sort_values(by='birth_date')
postvaccine_df
# Out:
#        mat_age    income mat_edu  depression  anxiety  birth_age_wk  \
# 8084      26.3   99999.0     C/T         9.0     24.0         39.57
# 4392      30.7  124999.0     C/T        14.0     25.0         41.29
# 6471      27.2   39999.0     PhD        12.0     16.0         39.57
# 6639      34.8   39999.0     PhD        10.0     13.0         39.00
# 2180      28.4  174999.0     C/T         3.0     11.0         40.71
# ...        ...       ...     ...         ...      ...           ...
# 10105     35.9  124999.0     C/T        10.0     19.0         37.71
# 160       38.6  200000.0       M         1.0     11.0         38.86
# 9272      33.1  174999.0      UG         7.0     18.0         38.14
# 5715      29.9  200000.0     PhD        11.0      9.0         41.00
# 5523      35.7  149999.0       M         4.0     10.0         40.86
#
#       birth_date  birth_length_cm  birth_weight_g delivery  NICU  life_danger  \
# ...

# %%
# Define a function to perform linear regression and print results
def perform_linear_regression(data):
    X = data[['depression', 'anxiety']]
    y = data['birth_weight_g']

    model = LinearRegression()
    model.fit(X, y)

    # Extracting model coefficients and intercept
    coefficients = model.coef_
    intercept = model.intercept_

    print(f'Regression coefficients: {coefficients}')
    print(f'Intercept: {intercept}')

# Applying the function to the prevaccine and postvaccine subsets
print("Pre-vaccine period:")
perform_linear_regression(prevaccine_df)

print("\nPost-vaccine period:")
perform_linear_regression(postvaccine_df)
# Out:
# Pre-vaccine period:
# Regression coefficients: [-7.78318695  4.04060493]
# Intercept: 3423.739573303964
#
# Post-vaccine period:
# Regression coefficients: [-3.23921234 -0.86587632]
# Intercept: 3443.0196095597166

# %% [markdown]
# **Pre-vaccine period:**
#
# The coefficients for depression and anxiety are -7.78318695 and 4.04060493, respectively, and the intercept is about 3423.74 grams.
# This suggests that, on average, an increase of one unit in depression scores is associated with a decrease of approximately 7.78 grams in birth weight. Similarly, an increase of one unit in anxiety scores is associated with an increase of approximately 4.04 grams in birth weight during the pre-vaccine period.
#
# **Post-vaccine period:**
#
# The coefficients for depression and anxiety are -3.23921234 and -0.86587632, respectively, with an intercept of about 3443.02 grams.
# This implies that, on average, an increase of one unit in depression scores is associated with a decrease of approximately 3.24 grams in birth weight. Conversely, an increase of one unit in anxiety scores is associated with a decrease of approximately 0.87 grams in birth weight during the post-vaccine period.
#
#
# **Analysis:**
#
# The impact of depression on birth weight appears to be stronger in the pre-vaccine period compared to the post-vaccine period. This could be due to various factors, including changes in the external environment, healthcare practices, or the psychological impact of the pandemic over time. However, one explanation may be that the depression was more severe in the pre df. Interestingly, while anxiety was associated with an increase in birth weight in the pre-vaccine period, it's associated with a decrease in the post-vaccine period. This could suggest that the nature of anxiety or its effects may have changed after the vaccine became available. It might be that post-vaccine anxiety is less related to stress that affects birth weight or that the composition of the population with higher anxiety changed post-vaccine. It is also important to note that the intercepts, which indicate the expected birth weight when depression and anxiety scores are zero, are higher in the post-vaccine period.

# %%
# Perform pairplots for each subset
pairplot_pre = sns.pairplot(prevaccine_df[['life_danger', 'anxiety', 'depression']])
pairplot_pre.fig.suptitle('Pre-Vaccine Pairplot of Life_danger, Anxiety, and Depression', y=1.02)

pairplot_post = sns.pairplot(postvaccine_df[['life_danger', 'anxiety', 'depression']])
pairplot_post.fig.suptitle('Post-Vaccine Pairplot of Life_danger, Anxiety, and Depression', y=1.02)

plt.show()

# %% [markdown]
# **Pre-Vaccine Pairplot:**
#
# Life_danger Distribution: The histogram suggests a right skewed distribution with a concentration of lower scores and fewer high scores. Anxiety Distribution: The histogram for anxiety shows a normal-like, right skewed distribution with a peak around the middle of the distribution, indicating that most individuals reported lower anxiety levels. Depression Distribution: Similar to anxiety, depression scores also show a right skewed distribution with a peak near the middle of the scores, around 13-14. Scatterplots: The scatterplots do show a linear relationship between anxiety and depression. There is some density observed in the lower score regions for all plots, which is consistent with the histograms.
#
# **Post-Vaccine Pairplot:**
#
# Life_danger Distribution: The distribution remains right skewed, however the it appears bimodal with a larger proporiton of the group having lower responses to general life danger. Anxiety Distribution: The distribution of anxiety seems to have shifted slightly towards the lower end, with the peak of the histogram moving downwards. Still right skewed. Depression Distribution: The distribution of depression has also shifted, showing a lower maximum depression score, with a peak around 5-6, as opposed the 13-14 from pre. Scatterplots: The scatterplots still show linear correlations between anxiety and depression. However the fewer data of the post df makes this harder to see.
#
# From a statistical standpoint, there seems to be a slight improvement in the distribution of the scores, with fewer individuals reporting higher levels of life_danger, anxiety, and depression post-vaccine. It's important to note that correlation does not imply causation, and any inference about the effect of the vaccine on these psychological variables would require a proper statistical analysis considering other factors and potential confounders.

# %%
prevaccine_df.dtypes
# Out:
# mat_age                   float64
# income                    float64
# mat_edu                    object
# depression                float64
# anxiety                   float64
# birth_age_wk              float64
# birth_date         datetime64[ns]
# birth_length_cm           float64
# birth_weight_g            float64
# delivery                   object
# NICU                        int64
# life_danger                 int64
# baby_danger                 int64
# virus_baby_harm             int64
# prob_preg                   int64
# dtype: object

# %%
# Calculate the Pearson correlation coefficient and p-value for pre-vaccine
correlation_pre_anxiety, p_value_pre_anxiety = pearsonr(prevaccine_df['life_danger'], prevaccine_df['anxiety'])
correlation_pre_depression, p_value_pre_depression = pearsonr(prevaccine_df['life_danger'], prevaccine_df['depression'])

# Calculate the Pearson correlation coefficient and p-value for post-vaccine
correlation_post_anxiety, p_value_post_anxiety = pearsonr(postvaccine_df['life_danger'], postvaccine_df['anxiety'])
correlation_post_depression, p_value_post_depression = pearsonr(postvaccine_df['life_danger'], postvaccine_df['depression'])

# Print the results
print(f"Pre-vaccine Anxiety Correlation: {correlation_pre_anxiety}, P-value: {p_value_pre_anxiety}")
print(f"Pre-vaccine Depression Correlation: {correlation_pre_depression}, P-value: {p_value_pre_depression}")
print(f"Post-vaccine Anxiety Correlation: {correlation_post_anxiety}, P-value: {p_value_post_anxiety}")
print(f"Post-vaccine Depression Correlation: {correlation_post_depression}, P-value: {p_value_post_depression}")
# Out:
# Pre-vaccine Anxiety Correlation: 0.3598213052110457, P-value: 4.626079112087198e-90
# Pre-vaccine Depression Correlation: 0.2950326667581357, P-value: 8.600694158875852e-60
# Post-vaccine Anxiety Correlation: 0.45193043980236713, P-value: 0.00015741927767761843
# Post-vaccine Depression Correlation: 0.3689289241906914, P-value: 0.002493381471236656

# %% [markdown]
# The results of the Pearson correlation coefficient and p-value for both pre-vaccine and post-vaccine data give us a quantitative measure of the strength and direction of the linear relationship between life_danger and the psychological variables of anxiety and depression.
#
# **Pre-Vaccine Data:**
#
# Anxiety Correlation: There is a moderate positive correlation (r ≈ 0.360) between life_danger and anxiety levels, suggesting that individuals with higher life_danger scores tend to report higher anxiety levels. The p-value is about 4.62e-90, which is extremely small, much less than the standard significance level of 0.05, indicating that this result is statistically significant.
#
# Depression Correlation: There is a weak to moderate positive correlation (r ≈ 0.0.295) between life_danger and depression levels. However, the p-value is  8.60e-60, which is also extremely small, suggesting that this result is statistically significant.
#
# **Post-Vaccine Data:**
#
# Anxiety Correlation: The correlation between life_danger and anxiety levels post-vaccine is lower (r ≈ 0.452) than in the pre-vaccine data. The p-value is about 0.0002 < .05, which strongly suggests that the correlation is statistically significant.
#
# Depression Correlation: Similar to anxiety, there is a moderate positive correlation (r ≈ 0.369) between life_danger and depression levels post-vaccine. The  small p-value of about 0.002 < 0.05, again indicates a statistically significant result.
#
# **Overall Interpretation:**
#
# The correlations for both anxiety and depression with life_danger are positive in both the pre-vaccine and post-vaccine scenarios, which means that as the perception of life being threatened increases, so do the reported levels of anxiety and depression.
#
# Post-vaccine, the correlation coefficients are both higher. This could imply an increase in the strength of the relationship between life_danger and the psychological measures after vaccination, possibly suggesting an overall unhelpful effect of the vaccine on psychological well-being. However, the change in the strength of the correlation is moderate/small and could be influenced by other factors.
#
# The p-values in the post-vaccine data are much smaller than in the pre-vaccine data, this is perhaps due to the discrepency between the size of the two populations we are comparing, as it may be harder to see the true relationship in the post df, since we have fewer observations.

# %%
def logistic_regression_plot(df, outcome):
    # Perform logistic regression
    X = df[['life_danger']].values  # 2D array for sklearn
    y = df[outcome].values  # Outcome
    log_reg = LogisticRegression()
    log_reg.fit(X, y)
    X_min = df['life_danger'].min()  # Get the minimum value
    X_max = df['life_danger'].max()  # Get the maximum value

    # Generate predicted probabilities for a range of 'life_danger' values
    X_test = np.linspace(X_min, X_max, 300).reshape(-1, 1)  # Reshaped for sklearn
    y_prob = log_reg.predict_proba(X_test)[:, 1]  # Probability of the outcome

    # Plotting the results
    plt.figure(figsize=(10, 6))
    plt.scatter(X, y, alpha=0.2, label='Actual Outcomes')  # Plot the actual data
    plt.plot(X_test, y_prob, color='red', label='Predicted Probability')  # Plot the predicted probabilities
    plt.title(f'life_danger Score vs. {outcome} Probability')
    plt.xlabel('life_danger Score')
    plt.ylabel(f'{outcome} Probability')
    plt.legend()
    plt.show()

    return log_reg

log_reg_pre = logistic_regression_plot(prevaccine_df, 'NICU')
log_reg_post = logistic_regression_plot(postvaccine_df, 'NICU')

# %% [markdown]
# **Pre-Vaccine Analysis:**
#
# The scatter plot shows the actual outcomes (NICU Stay or not) against the life_danger scores before vaccination. The red line represents the predicted probability of a NICU Stay based on the life_danger scores. As observed, there's a general trend where higher life_danger scores tend to correspond to higher predicted probabilities of NICU Stay. This suggests that individuals with higher life_danger scores were more likely to experience a NICU Stay before vaccination. However, there's a considerable amount of variability in the data, as indicated by the spread of points around the predicted probability line.
#
#
# **Post-Vaccine Analysis:**
#
# Similarly, the scatter plot shows the actual outcomes against the life_danger scores after vaccination. The red line represents the predicted probability of a NICU Stay based on the life_danger scores post-vaccination. Compared to the post-vaccine plot, there seems to be a slight shift downwards in the predicted probability line pre-vaccination, especially for higher life_danger scores. This suggests that post-vaccination, individuals with the same life_danger scores might have higher predicted probabilities of experiencing a NICU Stay compared to pre-vaccination.
#
# Overall, these plots provide a visual representation of how life_danger scores relate to the likelihood of NICU Stay before and after vaccination. It appears that vaccination may have no to hurtful impact on reducing the predicted probability of NICU Stay, especially for individuals with higher life_danger scores. However, further analysis and consideration of other factors are necessary to draw definitive conclusions about the vaccine's effect on NICU Stay probability. As, again the size of the post population is not large.

# %%
import statsmodels.api as sm
import pandas as pd

# Copy the DataFrames to avoid SettingWithCopyWarning
prevaccine_df = prevaccine_df.copy()
postvaccine_df = postvaccine_df.copy()

# Define the function to perform logistic regression and obtain p-values
def logistic_regression_with_p_values(df):
    # Prepare the data
    X = df[['baby_danger', 'virus_baby_harm']]
    y = df['NICU']

    # Initialize and fit the logistic regression model
    model = sm.Logit(y, sm.add_constant(X))
    result = model.fit()

    # Get the summary of the logistic regression model
    summary = result.summary2()
    p_values = result.pvalues

    return summary, p_values

# Perform logistic regression on prevaccine_df
prevaccine_summary, prevaccine_p_values = logistic_regression_with_p_values(prevaccine_df)

# Perform logistic regression on postvaccine_df
postvaccine_summary, postvaccine_p_values = logistic_regression_with_p_values(postvaccine_df)

# Show the summary and p-values for prevaccine_df
print("Pre-Vaccine Logistic Regression Summary:")
print(prevaccine_summary)
print("P-values:")
print(prevaccine_p_values)

# Show the summary and p-values for postvaccine_df
print("\nPost-Vaccine Logistic Regression Summary:")
print(postvaccine_summary)
print("P-values:")
print(postvaccine_p_values)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.306235
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.298914
#          Iterations 7
# Pre-Vaccine Logistic Regression Summary:
#                          Results: Logit
# ...
# Model:              Logit            Method:           MLE
# Dependent Variable: NICU             Pseudo R-squared: 0.006
# Date:               2024-03-20 23:02 AIC:              1796.2490
# No. Observations:   2923             BIC:              1814.1901
# Df Model:           2                Log-Likelihood:   -895.12
# Df Residuals:       2920             LL-Null:          -900.25
# Converged:          1.0000           LLR p-value:      0.0059311
# No. Iterations:     6.0000           Scale:            1.0000
# ----------------------------------------------------------------
#                  Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ...

# %% [markdown]
# **Pre-Vaccine Model:**
#
# *Pseudo R-squared:* The value is 0.006, indicating a weak model that explains only a small variance in the dependent variable.
#
# *Coefficients:* Both predictors have small positive coefficients.
#
# - baby_danger: Coefficient = 0.0055, p-value = 0.1402
# - virus_baby_harm: Coefficient = 0.0028, p-value = 0.5391
#
# *Interpretation:* The p-values for both variables are greater than the common alpha level of 0.05, which suggests that neither is statistically significant in predicting the likelihood of NICU stay in the pre-vaccine data set.
#
#
# **Post-Vaccine Model:**
#
# *Pseudo R-squared:* The value is slightly higher at 0.029, but it still indicates a weak model.
#
# *Coefficients:* Similar to the pre-vaccine model, the coefficients are small and positive.
#
# - baby_danger: Coefficient = 0.0244, p-value = 0.2985
# - virus_baby_harm: Coefficient = -0.0135, p-value = 0.5433
#
# *Interpretation:* Again, since the p-values are above 0.05, there is no statistically significant association between these predictors and the likelihood of NICU stay for the post-vaccine period.
#
#
# **Overall Analysis:**
#
# The results are consistent across both pre-vaccine and post-vaccine models, showing no significant predictors among the variables analyzed.
# The Pseudo R-squared values in both models are low, indicating that other variables not included in the model may better explain the variance in NICU stay.
#
# The constant term (const) is significant in both models, indicating that there are other factors not captured by the two predictors that are influencing the NICU stay.
#
# **Conclusion:**
#
# - The variables baby_danger and virus_baby_harm do not have a statistically significant impact on the likelihood of a newborn's stay in the NICU, based on the data and models presented.
# - Since the model does not explain much of the variability in NICU stays, it may be useful to consider additional variables that could have a stronger relationship with the outcome. This might include medical history, health indicators, or other socioeconomic factors.

# %% [markdown]
# ## Second Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
# Example of dropping rows with any missing values in specified columns
df = df.dropna(subset=['income', 'depression', 'anxiety', 'NICU'])

# Recalculate income groups after handling missing values
df['income_group'] = pd.qcut(df['income'], q=4, labels=False)

print(df['income_group'].unique())


# Perform logistic regression within each income group
for group in df['income_group'].unique():
    group_df = df[df['income_group'] == group]
    logit_model = sm.Logit(group_df['NICU'], group_df[['depression', 'anxiety']]).fit()
    print(f'Income Group: {group}')
    print(logit_model.summary())
# Out:
# [2 3 1 0]
# Optimization terminated successfully.
#          Current function value: 0.355858
#          Iterations 6
# Income Group: 2
#                            Logit Regression Results
# ...
# Dep. Variable:                   NICU   No. Observations:                 1431
# Model:                          Logit   Df Residuals:                     1429
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 20 Mar 2024   Pseudo R-squ.:                -0.09518
# Time:                        23:02:39   Log-Likelihood:                -509.23
# converged:                       True   LL-Null:                       -464.97
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# **General Observations:**
#
# Model Convergence: All models have successfully converged, which suggests that the optimization algorithm was able to find a solution that best fits the data for each income group.
#
# Pseudo R-squared Values: The negative pseudo R-squared values across all groups are unusual and typically indicate a poor fit of the model to the data. This metric suggests that the models may not adequately capture the variance in NICU admissions based on the predictors used.
#
# LLR p-value: The LLR (Likelihood Ratio Test) p-value being 1.000 across all groups suggests no improvement over the null model, which contains no predictors and only an intercept. This could indicate that the predictors might not be strongly associated with the outcome, at least not in a linear manner as modeled.
#
# **Income Group 2:**
#
# Depression has a positive coefficient (0.1218), indicating an association with increased likelihood of NICU admission, significant at the 0.000 level. Anxiety has a negative coefficient (-0.1806), suggesting it's associated with a decreased likelihood of NICU admission, also significant at the 0.000 level.
#
# **Income Group 3:**
#
# Depression's effect is smaller (0.0692) but still positively associated with NICU admissions, with a p-value of 0.033, indicating marginal significance. Anxiety remains negatively associated (-0.1615), significantly reducing the likelihood of NICU admission.
#
# **Income Group 1:**
#
# Depression has a significant positive association (0.1012) with NICU admissions, with a p-value of 0.002. Anxiety also shows a significant negative association (-0.1725), similar to the other groups. Income Group 0:
#
# Both depression (0.0957) and anxiety (-0.1606) show significant associations similar to other groups, with depression increasing and anxiety decreasing the likelihood of NICU admission.
#
# Recommendations for Future Research: Given the unexpected findings, such as the negative pseudo R-squared values and the LLR p-value of 1.000, future research should consider several avenues for improvement. For future research on NICU admission prediction, it's crucial to refine the model by incorporating non-linear relationships and additional predictors to capture the complex dynamics at play. Emphasizing thorough data preparation and exploring advanced modeling techniques, such as machine learning algorithms, will be essential for enhancing predictive accuracy. Addressing class imbalance with techniques like SMOTE and employing comprehensive evaluation metrics suited for imbalanced data will further ensure the development of robust models. These steps promise significant improvements in modeling NICU admissions, offering valuable insights for healthcare decision-making.

# %%
# Assuming df is your DataFrame and already preprocessed

# Splitting the dataset into training and test sets
X = df[['income', 'depression', 'anxiety']]  # Predictor variables
y = df['NICU']  # Target variable

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train, y_train)
rf_predictions = rf_clf.predict(X_test)

print("Random Forest Classifier Performance:")
print("Accuracy:", accuracy_score(y_test, rf_predictions))
print(classification_report(y_test, rf_predictions))

# Gradient Boosting Classifier
gbm_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gbm_clf.fit(X_train, y_train)
gbm_predictions = gbm_clf.predict(X_test)

print("Gradient Boosting Classifier Performance:")
print("Accuracy:", accuracy_score(y_test, gbm_predictions))
print(classification_report(y_test, gbm_predictions))
# Out:
# Random Forest Classifier Performance:
# Accuracy: 0.8752424046541694
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93      1396
#            1       0.10      0.03      0.05       151
#
#     accuracy                           0.88      1547
#    macro avg       0.50      0.50      0.49      1547
# weighted avg       0.82      0.88      0.85      1547
#
# Gradient Boosting Classifier Performance:
# Accuracy: 0.9004524886877828
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1396
#            1       0.00      0.00      0.00       151
#
#     accuracy                           0.90      1547
#    macro avg       0.45      0.50      0.47      1547
# weighted avg       0.81      0.90      0.86      1547

# %% [markdown]
# **Random Forest Classifier Performance:**
#
# *Accuracy:*<br> The overall accuracy of 87.52% indicates that the model correctly predicted whether a newborn would have a NICU stay in approximately 87.52% of the cases in your test set. While this might seem high, accuracy alone can be misleading, especially in imbalanced datasets.
#
# *Precision (for class 1):* <br>
# At 10%, precision for predicting NICU stays (class 1) is low, meaning that when the model predicts a NICU stay, it is correct only 10% of the time.
#
# *Recall (for class 1):* <br>
# The recall for NICU stays is 3%, indicating that out of all actual NICU stays, the model correctly identifies only 3% of them.
#
# *F1-score (for class 1):* <br>
# The F1-score for NICU stays is 5%, which is a weighted average of precision and recall. This low score suggests that the model performs poorly in predicting NICU stays accurately.
#
# *Gradient Boosting Classifier Performance:*<br>
# Accuracy: The accuracy here is slightly higher at 90.04%, indicating a small improvement over the Random Forest model in correctly predicting both NICU stays and non-NICU stays across all cases.
#
# *Precision (for class 1):*<br>
# Precision for NICU stays is reported as 0%, which suggests the model never correctly predicts positive NICU stays (or it possibly never predicts a positive class due to the model's bias towards the majority class).
#
# *Recall (for class 1):* <br>
# The recall is also 0% for NICU stays, indicating the model fails to identify any actual NICU cases.
#
# *F1-score (for class 1):* <br>
# Similarly, the F1-score is 0%, confirming poor performance in predicting positive cases of NICU stays.
#
# *Interpretation and Next Steps:* <br>
# Imbalanced Dataset: The significant difference in performance metrics between class 0 (non-NICU stays) and class 1 (NICU stays) suggests that your dataset is imbalanced, with much fewer NICU stay instances than non-NICU stays. Models tend to perform well on the majority class but poorly on the minority class in such scenarios.
#
# *Model Bias:* <br>
# Both models show a strong bias towards predicting the majority class (non-NICU stays), as evidenced by the high accuracy but very low precision, recall, and F1-score for the NICU stay predictions.

# %%
# Adjusting class weights to address imbalance
class_weights = 'balanced'  # Automatically adjust weights inversely proportional to class frequencies

# Random Forest Classifier with class weights
rf_clf = RandomForestClassifier(n_estimators=100, class_weight=class_weights, random_state=42)
rf_clf.fit(X_train, y_train)

# Predictions
predictions = rf_clf.predict(X_test)

# Model Evaluation
print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))

# Confusion Matrix
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# ROC Curve and AUC
fpr, tpr, _ = roc_curve(y_test, rf_clf.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 0.7950872656755009
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      1396
#            1       0.10      0.13      0.11       151
#
#     accuracy                           0.80      1547
#    macro avg       0.50      0.50      0.50      1547
# weighted avg       0.82      0.80      0.81      1547

# %% [markdown]
# **Confusion Matrix Analysis:**
#
# True Negatives (TN): The model correctly predicted 'no NICU stay' 1211 times.<br>
# False Positives (FP): The model incorrectly predicted 'NICU stay' when there was none 185 times.<br>
# False Negatives (FN): The model incorrectly predicted 'no NICU stay' when there was a NICU stay 132 times.<br>
# True Positives (TP): The model correctly predicted 'NICU stay' 19 times.<br>
#
# The high number of true negatives indicates that the model is better at predicting the majority class ('no NICU stay'). However, the number of false negatives and false positives indicates a challenge in accurately predicting the minority class ('NICU stay').
#
# **Classification Report Analysis:**
#
# Precision for Class 0 is high (0.90), meaning that when the model predicts 'no NICU stay,' it is usually correct.
# Recall for Class 0 is also quite high (0.87), which means the model is able to identify most of the 'no NICU stay' instances.
# F1-score for Class 0 combines precision and recall into a single measure (0.88), indicating good performance for the majority class.
# Conversely, for the minority class ('NICU stay'):
#
# Precision for Class 1 is low (0.09), so when the model predicts a NICU stay, it is correct only a small fraction of the time.
# Recall for Class 1 is also low (0.13), indicating that the model misses a lot of actual NICU stays.
# F1-score for Class 1 is very low (0.11), showing that the model performs poorly for the minority class.
# ROC Curve and AUC Analysis:
# The ROC curve is close to the diagonal line, with an AUC of 0.49. An AUC of 0.5 would indicate a model that performs no better than random chance, so an AUC of 0.49 suggests that the model is not effectively distinguishing between the 'NICU stay' and 'no NICU stay' classes.
# Overall Interpretation:
# The accuracy of 79.5% might seem reasonably high, but it is misleading given the class imbalance. The majority class ('no NICU stay') is driving the accuracy, while the model struggles with the minority class ('NICU stay').
# The model exhibits poor performance in identifying true NICU cases, which is a significant concern in a healthcare setting where the cost of a false negative (not identifying a needed NICU stay) can be critical.
# The AUC of 0.49 further indicates that the model is not better than random guessing when it comes to distinguishing between the classes.

# %%
prevaccine_df.dropna(inplace=True)

# Define the independent variables and dependent variable
X = prevaccine_df.drop('prob_preg', axis=1)  # Independent variables
y = prevaccine_df['prob_preg']  # Dependent variable

categorical_cols = ['income', 'mat_edu', 'birth_date', 'delivery', 'NICU']
numerical_cols = ['mat_age', 'depression', 'anxiety', 'birth_age_wk', 'birth_length_cm', 'birth_weight_g', 'life_danger', 'baby_danger','virus_baby_harm']

# Create a ColumnTransformer to apply one-hot encoding to categorical columns
preprocessor = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), categorical_cols)],
    remainder='passthrough'
)

# Fit the ColumnTransformer on data and transform 'X'
X_encoded = preprocessor.fit_transform(X)
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize and fit the logistic regression model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred = log_reg.predict(X_test)

# Evaluate the model's performance
print("Classification Report: For Pre-Vaccine Dataframe")
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
print("Variable : Coefficient (Change in log-odds per 1 unit increase)")

# Display the coefficients and corresponding variable names
coefficients = log_reg.coef_[0]
variable_names = preprocessor.named_transformers_['encoder'].get_feature_names_out(input_features=categorical_cols)
for coef, var_name in zip(coefficients, variable_names):
    print(f"{var_name}: {coef}")

non_categorical_coeffs = log_reg.coef_[0][len(categorical_cols):]  # Exclude coefficients of one-hot encoded variables
# Get the names of the non-categorical variables
non_categorical_var_names =  numerical_cols #Assuming original_feature_names contains the names of non-categorical variables

# Display the coefficients of the non-categorical variables
for coef, var_name in zip(non_categorical_coeffs, non_categorical_var_names):
    print(f"{var_name}: {coef}")
# Out:
# Classification Report: For Pre-Vaccine Dataframe
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.78       353
#            1       0.74      0.32      0.45       229
#
#     accuracy                           0.69       582
#    macro avg       0.71      0.62      0.61       582
# weighted avg       0.70      0.69      0.65       582
#
# Accuracy: 0.6872852233676976
#
#
# Variable : Coefficient (Change in log-odds per 1 unit increase)
# income_20000.0: 0.000834427682072276
# income_39999.0: 0.001939696811289777
# income_69999.0: -0.0010047808139544271
# income_99999.0: -0.008187518134243996
# income_124999.0: 0.010578681166040967
# income_149999.0: -9.759004669804836e-05
# income_174999.0: -0.00371030450171144
# income_199999.0: 0.0005036263891226474
# income_200000.0: 0.0016360993273807738
# mat_edu_<HS: 0.0008043530352577902
# mat_edu_C/T: 0.007613046689619581
# mat_edu_HS: 0.005645921796367737
# ...

# %%
postvaccine_df.dropna(inplace=True)

# Define the independent variables and dependent variable
X = postvaccine_df.drop('prob_preg', axis=1)  # Independent variables
y = postvaccine_df['prob_preg']  # Dependent variable

categorical_cols = ['income', 'mat_edu', 'birth_date', 'delivery', 'NICU']
numerical_cols = ['mat_age', 'depression', 'anxiety', 'birth_age_wk', 'birth_length_cm', 'birth_weight_g', 'life_danger', 'baby_danger','virus_baby_harm']

# Create a ColumnTransformer to apply one-hot encoding to categorical columns
preprocessor = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), categorical_cols)],
    remainder='passthrough'
)

# Fit the ColumnTransformer on data and transform 'X'
X_encoded = preprocessor.fit_transform(X)
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize and fit the logistic regression model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred = log_reg.predict(X_test)

# Evaluate the model's performance
print("Classification Report: For Pre-Vaccine Dataframe")
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
print("Variable : Coefficient (Change in log-odds per 1 unit increase)")

# Display the coefficients and corresponding variable names
coefficients = log_reg.coef_[0]
variable_names = preprocessor.named_transformers_['encoder'].get_feature_names_out(input_features=categorical_cols)
for coef, var_name in zip(coefficients, variable_names):
    print(f"{var_name}: {coef}")

non_categorical_coeffs = log_reg.coef_[0][len(categorical_cols):]  # Exclude coefficients of one-hot encoded variables
# Get the names of the non-categorical variables
non_categorical_var_names =  numerical_cols #Assuming original_feature_names contains the names of non-categorical variables

# Display the coefficients of the non-categorical variables
for coef, var_name in zip(non_categorical_coeffs, non_categorical_var_names):
    print(f"{var_name}: {coef}")
# Out:
# Classification Report: For Pre-Vaccine Dataframe
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        10
#            1       0.20      0.33      0.25         3
#
#     accuracy                           0.54        13
#    macro avg       0.47      0.47      0.46        13
# weighted avg       0.62      0.54      0.57        13
#
# Accuracy: 0.5384615384615384
#
#
# Variable : Coefficient (Change in log-odds per 1 unit increase)
# income_39999.0: 0.01939530180382613
# income_69999.0: 0.011130035099891224
# income_99999.0: 0.002839566435756263
# income_124999.0: 0.01030094424448348
# income_149999.0: 0.004623636022109909
# income_174999.0: -0.0342770349922274
# income_199999.0: 0.00687593429752791
# income_200000.0: -0.019788937674101007
# mat_edu_C/T: -0.0073491212804785815
# mat_edu_HS: 0.037285310406731116
# mat_edu_M: -0.018096882109367447
# mat_edu_PhD: -0.012027663078334168
# mat_edu_UG: 0.001287801298682772
# ...

# %% [markdown]
# Our study's analysis of both non-categorical and categorical data provides comprehensive insights into the factors influencing pregnancy outcomes during the COVID-19 pandemic, before and after the vaccine rollout. For non-categorical data, we observed nuanced shifts in the impact of delivery mode, NICU admissions, maternal age, mental health indicators, birth metrics, and perceived risks on pregnancy outcomes. Cesarean deliveries consistently favored better outcomes compared to vaginal deliveries, though this effect became less pronounced post-vaccine. NICU admissions maintained a positive association with favorable outcomes across both periods, albeit with a reduced effect post-vaccine. A notable shift was observed in maternal age, where its slightly negative impact pre-vaccine became more pronounced post-vaccine, suggesting an increasing influence of maternal age on outcomes as the pandemic progressed. Mental health factors also shifted, with depression moving from a slight negative to a positive association with favorable outcomes, and anxiety showing a stronger negative effect post-vaccine. Birth metrics revealed changing dynamics, particularly with birth length gaining importance post-vaccine. Perceived risks to the mother and baby showed varied impacts, highlighting changing perceptions and realities of risk throughout the pandemic.
#
# Categorical data analysis revealed complex patterns in how income brackets and maternal education levels affected the probability of problematic pregnancy outcomes. Income's impact varied significantly, without a clear linear trend, reflecting the multifaceted nature of socioeconomic influences on health. High-income brackets showed a shift from slight risk increase pre-vaccine to risk decrease post-vaccine, suggesting evolving socioeconomic dynamics. Middle-income bracket effects varied, indicating the presence of other influencing factors. Educational gradients suggested that higher education levels were generally associated with lower probabilities of problematic pregnancies, though shifts in the impacts of specific education levels post-vaccine hinted at changing socioeconomic and health behavior dynamics.
#
# In conclusion, our findings underscore the intricate interplay of delivery methods, NICU admissions, maternal demographics, mental health, birth metrics, perceived risks, income levels, and education on pregnancy outcomes during the pandemic. These insights call for a nuanced, multi-faceted approach to maternal and infant health care, emphasizing the importance of mental health support, socioeconomic support, and informed healthcare decisions during such global crises. Future strategies should aim to mitigate the adverse impacts observed and leverage the protective factors identified, enhancing care and support for pregnant women and their babies in the face of ongoing and future health challenges.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The dataset from the Pregnancy during the COVID-19 Pandemic (PdP) project might exhibit biases such as geographic concentration (limited to Canada, possibly not reflecting experiences in other healthcare systems or cultures), socio-economic and educational disparities (respondents may skew towards certain income or education levels based on survey reach and accessibility), and potential language barriers (despite survey language options, nuances in understanding or expression may affect responses). The variables we used such as the Edinburgh Postnatal Depression Scale and the PROMIS Anxiety score are both established statistical measurements in research that have already gotten consent from participants to not only partake in the research but to give permission to publish the findings, so though we are looking at their numerical measurements we’ve ensured the ethics and privacy of those numbers. We will not investigate or research these individuals' personal information, as confidentiality is key and limits the biases of the data. We will ensure that no personal identifiers are included in the dataset and that any published results cannot be traced back to individual participants. We plan to use the data for educational purposes only to find correlations between mental health and pregnancy outcomes.
#
# To account for biases, especially in the socio-economic and educational disparities, we will categorize them which will allow us to be transparent to audience members and those reading our reports. We will address how these biases can potentially skew our data and conclusions because we have a limited amount of data due to the evolving nature of the COVID-19 pandemic. We will also seek to understand how these backgrounds could influence the respondents' experiences and responses, particularly those regarding mental health during pregnancy amid the pandemic.

# %% [markdown]
# # Discussion and Conclusion
#
# In this study, we’ve explored the impact of the COVID-19 pandemic on pregnant women and dived into the relationship between mental health and pandemic-related stressors and their potential effects on childbirth outcomes. Anchored by data from the Pregnancy during the COVID-19 Pandemic project (PdP), we’ve done an analytical approach by utilizing pairplot visualizations, correlation analyses, and logistic regression.
# Our study revealed that perceived pandemic threat levels consistently aligned with negative mental health indicators, such as anxiety and depression, during pre and post-vaccine periods. These findings underscore the impact of pandemic-related stress on maternal mental well-being. Through our pairplot analysis, we observed a clear shift towards lower scores of life danger, anxiety, and depression following the vaccine rollout, suggesting an alleviation of these mental health stressors post-vaccination.
#
# Furthermore, our correlation analyses supported these findings by showing a positive association between perceived life danger and mental health distress indicators, with post-vaccine data indicating even higher correlation coefficients. The p-values obtained suggested a strong statistical significance, despite a potential reduction in data density post-vaccine.
#
# However, our logistic regression analysis demonstrated a more nuanced picture, While mental health stressors correlated with perceived threats, they did not predict NICU admissions, highlighting the complex nature of childbirth outcomes and the potential influence of other unmeasured variables. Analyzing categorical data, we observed no clear linear trend in how income and education levels impacted pregnancy outcomes, reflecting the complex interplay of socioeconomic factors. Shifts in the effects of income brackets and education levels post-vaccine suggest changing socioeconomic and behavioral influences on pregnancy outcomes.
#
# Our study also monitored the trend of problematic pregnancies over time, revealing a significant decrease coinciding with the start of COVID-19 vaccinations, and a further drop to lower levels, indicating an emerging respite from the height of the pandemic’s impact. These results suggest an improvement in pregnancy outcomes in the vaccine availability.
#
# In conclusion, the data from this study not only reveal the benefits of the vaccine in reducing mental health stressors among pregnant women but also emphasize the importance of mental health care during high-stress events like a pandemic. While the perceived threat of COVID-19 did not directly predict NICU admissions, it is clear that the pandemic stress had a significant impact on maternal mental health.
#
# This research contributes a perspective on pregnancy during pandemics, advocating for a holistic approach to healthcare. It calls for strategies that address the physiological risks and diseases during pregnancy along with the psychological fears and stressors associated with childbirth.
#
# As the world continues with the ramifications of the COVID-19 pandemic, these insights from our study can help inform healthcare strategies that support pregnant women, enhance public health planning, and prepare us to better protect maternal and infant health during future global health crises
#
# **Limitations:**
#
# The limitations of this study are important for understanding the context of our findings and guiding future research. One significant limitation is the disparity in the number of observations between the pre-vaccine (2,923) and post-vaccine (65) subsets. This substantial difference could potentially skew the analysis, making it challenging to draw definitive conclusions about the impact of the vaccine rollout on pregnant women's mental health and childbirth outcomes. The smaller sample size in the post-vaccine period limits the statistical power of our analysis, making it more difficult to detect significant differences or trends that may exist.
#
# Another limitation is the study's reliance on self-reported data, which may introduce bias due to participants' subjective interpretation of their mental health status and experiences during the pandemic. Additionally, the study's focus on a Canadian population may limit the generalizability of the findings to other regions with different healthcare systems, pandemic responses, and vaccination rollouts. When we looked at our population data during our EDA, we found that our dataset lacked diversity in educational background, ethnicity, language spoken, and socioeconomic status, as the majority of our participants were white, from middle-class income homes, who held degrees and spoke English. This gives the applicability of our findings to be limited to the scope of the Canadian population which it was sampled from, lacking the ability to be compared to other countries and demographics of people. Though our group tried hard to find widespread published maternity mental health data over the pandemic, none had the multitude of variables and components of established research built into it like this dataset, which is why we made it our primary dataset.
#
# The timing and context of the vaccine rollout also represent a limitation. The initial phase of vaccine distribution prioritized certain populations, and pregnant women's eligibility and willingness to receive the vaccine during our post-vaccine study period may have varied widely. This variability could influence the observed outcomes and their association with mental health indicators.
#
# Future research should aim to address these limitations by including larger and more diverse post-vaccine samples to enhance the generalizability of the findings. Longitudinal studies that follow pregnant women through the pre-vaccine, vaccine rollout, and post-vaccine phases could provide more comprehensive insights into the pandemic's long-term effects on maternal mental health and childbirth outcomes. Additionally, investigating other factors that may influence these outcomes, such as healthcare access, socioeconomic status, and vaccination status, would offer a more nuanced understanding of the pandemic's impact on pregnant women. Further research could also explore interventions designed to mitigate the adverse effects of pandemic-related stress on pregnant women and their babies, thereby informing public health strategies and healthcare practices to better support this vulnerable population during global health crises.
#
#
#
#
#
#
#
#
# # Team Contributions
#
# * **Sophia Asraf** - Wrote code for the EDA and data cleaning, created graphs and models for pre and post vaccine, analyzed the graphs from EDA, created thorough analysis for the EDA
# * **Jake Kondo** - Organzied all documents including the notebooks, proofread all code and analysis, transferred and organized group's work into github, organized meeting times, created models for income
# * **Karun Mokha** - Reasearched heavily on our topic, generated our reasearch question along with inital analysis, generated the subquestions, initiated group meetings
# * **Dylan Oquendo** - Contributed on data cleaning and analysis, creating ideas for the question and our background, organized a google collab for us to code, communicated with professor for clarification
# * **Ekrem Ersoz** - Contirbuted on project proposal and assisted in findng data for the dataset, contributed to the slides and analysis
